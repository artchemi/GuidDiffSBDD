# %%
import numpy as np
import torch
import os, sys
# import py3Dmol
from pathlib import Path
import matplotlib.pyplot as plt

os.environ["MKL_THREADING_LAYER"] = "GNU"

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %% [markdown]
# # 1. Полный пайплайн генерации
